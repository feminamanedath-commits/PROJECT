# %% [markdown]
# <h1 style="color:blue; font-size:30px;">📊 Retail Analytics – 🎮 Gaming Sales</h1>

# %% [markdown]
# <h2 style="color:black; font-size:22px;">Phase 1: Data Loading and Pre-Processing</h2>

# %% [markdown]
# Aim : The aim of this project is to analyze global video game sales data, understand market trends, and generate insights into the performance of different consoles, genres, and publishers.

# %% [markdown]
# Problem Definition:The video game industry includes multiple consoles, genres, publishers, and developers competing across different regions (North America, Japan, PAL regions, and Others). However, sales performance varies significantly across platforms and regions.

# %% [markdown]
# <h2 style="font-size:20px; color:black; font-weight:bold; font-style:italic;">
# 📚 Step 1: Preparing the Environment:Library Import
# </h2>

# %%
import pandas as pd
import numpy as np

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# <h2 style="font-size:20px; color:black; font-weight:bold; font-style:italic;">
# 💾 Step 2: Loading the Dataset
# </h2>

# %%
df = pd.read_csv("gaming sales.csv")
df.head()
# Out:
#                                              img                        title  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3
#
#   console    genre       publisher       developer  critic_score  total_sales  \
# 0     PS3   Action  Rockstar Games  Rockstar North           9.4        20.32
# 1     PS4   Action  Rockstar Games  Rockstar North           9.7        19.39
# 2     PS2   Action  Rockstar Games  Rockstar North           9.6        16.15
# 3    X360   Action  Rockstar Games  Rockstar North           NaN        15.86
# 4     PS4  Shooter      Activision        Treyarch           8.1        15.09
#
# ...

# %% [markdown]
# <h2 style="font-size:20px; color:black; font-weight:bold; font-style:italic;">
# 📊 Step 3: Dataset Overview (Shape & Columns)
# </h2>

# %%
rows, columns = df.shape

print("Number of Rows:", rows)
print("Number of Columns:", columns)
# Out:
# Number of Rows: 64016
# Number of Columns: 14

# %% [markdown]
# <h2 style="font-size:20px; color:black; font-weight:bold; font-style:italic;">
# 🔎 Step 4: Inspecting Dataset Information
# </h2>

# %%
df.columns
# Out:
# Index(['img', 'title', 'console', 'genre', 'publisher', 'developer',
#        'critic_score', 'total_sales', 'na_sales', 'jp_sales', 'pal_sales',
#        'other_sales', 'release_date', 'last_update'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64016 entries, 0 to 64015
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           64016 non-null  object
#  1   title         64016 non-null  object
#  2   console       64016 non-null  object
#  3   genre         64016 non-null  object
#  4   publisher     64016 non-null  object
#  5   developer     63999 non-null  object
#  6   critic_score  6678 non-null   float64
#  7   total_sales   18922 non-null  float64
#  8   na_sales      12637 non-null  float64
#  9   jp_sales      6726 non-null   float64
#  10  pal_sales     12824 non-null  float64
#  11  other_sales   15128 non-null  float64
#  12  release_date  56965 non-null  object
#  13  last_update   17879 non-null  object
# dtypes: float64(6), object(8)
# memory usage: 6.8+ MB

# %% [markdown]
# Insights
# * Several columns contain missing values:• developer → 17 missing entries
# * critic_score → only ~6,678 non-null out of 64,016 (very sparse)
# * total_sales and regional sales columns (na_sales, jp_sales, pal_sales, other_sales) → large portions missing
# * release_date and last_update → many missing values as well

# %%
df.describe()
# Out:
#        critic_score   total_sales      na_sales     jp_sales     pal_sales  \
# count   6678.000000  18922.000000  12637.000000  6726.000000  12824.000000
# mean       7.220440      0.349113      0.264740     0.102281      0.149472
# std        1.457066      0.807462      0.494787     0.168811      0.392653
# min        1.000000      0.000000      0.000000     0.000000      0.000000
# 25%        6.400000      0.030000      0.050000     0.020000      0.010000
# 50%        7.500000      0.120000      0.120000     0.040000      0.040000
# 75%        8.300000      0.340000      0.280000     0.120000      0.140000
# max       10.000000     20.320000      9.760000     2.130000      9.850000
#
#         other_sales
# count  15128.000000
# mean       0.043041
# std        0.126643
# min        0.000000
# 25%        0.000000
# 50%        0.010000
# 75%        0.030000
# max        3.120000

# %% [markdown]
# Overview
# * The dataset is highly skewed: a small number of games achieve massive sales, while the majority sell modestly.
# * Critic scores cluster around 7–8, suggesting most games receive average-to-good reviews.
# * This highlights that blockbuster titles (like GTA V) drive overall sales figures, while most games remain niche.

# %%
df.isnull().sum()
# Out:
# img                 0
# title               0
# console             0
# genre               0
# publisher           0
# developer          17
# critic_score    57338
# total_sales     45094
# na_sales        51379
# jp_sales        57290
# pal_sales       51192
# other_sales     48888
# release_date     7051
# last_update     46137
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')
df['release_year'] = df['release_date'].dt.year

# %% [markdown]
# # Phase 1 Key Insights
#
# - The dataset contains 64,000 rows and 14 columns.
# - It includes categorical, numerical, and datetime features.
# - Missing values are present in critic_score column.
# - No duplicate records found.
# - Date column successfully converted to datetime format.
# - Dataset is ready for preprocessing in Phase 2.

# %%
import pandas as pd
import pandas as pd

# Load the original CSV into a DataFrame
df = pd.read_csv('gaming sales.csv')

# Check the first few rows to make sure it loaded
df.head()
# Out:
#                                              img                        title  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3
#
#   console    genre       publisher       developer  critic_score  total_sales  \
# 0     PS3   Action  Rockstar Games  Rockstar North           9.4        20.32
# 1     PS4   Action  Rockstar Games  Rockstar North           9.7        19.39
# 2     PS2   Action  Rockstar Games  Rockstar North           9.6        16.15
# 3    X360   Action  Rockstar Games  Rockstar North           NaN        15.86
# 4     PS4  Shooter      Activision        Treyarch           8.1        15.09
#
# ...

# %%
# Replace 'your_file.csv' with your actual CSV file name
df = pd.read_csv('gaming sales.csv')

# Check the first few rows
df.head()
# Out:
#                                              img                        title  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3
#
#   console    genre       publisher       developer  critic_score  total_sales  \
# 0     PS3   Action  Rockstar Games  Rockstar North           9.4        20.32
# 1     PS4   Action  Rockstar Games  Rockstar North           9.7        19.39
# 2     PS2   Action  Rockstar Games  Rockstar North           9.6        16.15
# 3    X360   Action  Rockstar Games  Rockstar North           NaN        15.86
# 4     PS4  Shooter      Activision        Treyarch           8.1        15.09
#
# ...

# %%
df = pd.read_csv(r'C:\Users\hp\Desktop\gaming sales.csv')

# %%
cleaned_df = df.dropna().drop_duplicates()

# Check first few rows of cleaned data
cleaned_df.head()
# Out:
#                                              img                       title  \
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg          Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg   Call of Duty: Black Ops 3
# 7  /games/boxart/full_4653215AmericaFrontccc.jpg       Red Dead Redemption 2
# 8  /games/boxart/full_1977964AmericaFrontccc.jpg  Call of Duty: Black Ops II
# 9  /games/boxart/full_4649679AmericaFrontccc.png  Call of Duty: Black Ops II
#
#   console             genre       publisher       developer  critic_score  \
# 1     PS4            Action  Rockstar Games  Rockstar North           9.7
# 4     PS4           Shooter      Activision        Treyarch           8.1
# 7     PS4  Action-Adventure  Rockstar Games  Rockstar Games           9.8
# 8    X360           Shooter      Activision        Treyarch           8.4
# 9     PS3           Shooter      Activision        Treyarch           8.0
#
# ...

# %%
import os
os.listdir()  # should show 'cleaned_data.csv' if saved in notebook folder
# Out:
# ['.ipynb_checkpoints',
#  '01_Data_Loading_and_Overview-2.ipynb',
#  '01_Data_Loading_and_Overview.ipynb',
#  'Data Pre Processing.ipynb',
#  'desktop.ini',
#  'Exploratory Data Analysis.ipynb',
#  'gaming sales.csv',
#  'GoTo.lnk',
#  'hilton.sabacloud.com_content_prodencryption_aOeuVMgiUt6lB2nz758ohg_1764798576_0216MDEzNnd1RGlVM25XZXo5VVRUQjBOQUFVSWJxcGlQVnlxSmhiQUxMUjNlT3JtQ0FLa3ZSbHVCbUpMOXhyTXU0cGNHTFp1SmRUb1VHN1c0VDc5ODBVZSt0eXhLSE9PakZUWngrenhrRFlaRnZkQ1ZZcUdYT2krSEowRXNvRndsb.pdf',
#  'Python Assignment 2.ipynb',
#  'Smart Browser.lnk',
#  'SmartPOS_v5.LNK',
#  'sms_exp - Shortcut (2).lnk',
#  'SNOONU STOCK.xlsx',
#  'STORE PRE- OPENING CHECKLIST.docx',
#  'WhatsApp Image 2026-02-19 at 1.04.49 AM.jpeg']

# %%
new_df = pd.read_csv('gaming sales.csv')
new_df.head()
# Out:
#                                              img                        title  \
# 0  /games/boxart/full_6510540AmericaFrontccc.jpg           Grand Theft Auto V
# 1  /games/boxart/full_5563178AmericaFrontccc.jpg           Grand Theft Auto V
# 2                    /games/boxart/827563ccc.jpg  Grand Theft Auto: Vice City
# 3  /games/boxart/full_9218923AmericaFrontccc.jpg           Grand Theft Auto V
# 4  /games/boxart/full_4990510AmericaFrontccc.jpg    Call of Duty: Black Ops 3
#
#   console    genre       publisher       developer  critic_score  total_sales  \
# 0     PS3   Action  Rockstar Games  Rockstar North           9.4        20.32
# 1     PS4   Action  Rockstar Games  Rockstar North           9.7        19.39
# 2     PS2   Action  Rockstar Games  Rockstar North           9.6        16.15
# 3    X360   Action  Rockstar Games  Rockstar North           NaN        15.86
# 4     PS4  Shooter      Activision        Treyarch           8.1        15.09
#
# ...

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("gaming sales.csv")

# Clean the dataset (drop missing values + duplicates)
cleaned_df = df.dropna().drop_duplicates()

# Save cleaned dataset to Excel
cleaned_df.to_excel("cleaned_gaming_sales.xlsx", index=False)

print("✅ Cleaned dataset saved as cleaned_gaming_sales.xlsx")
# Out:
# ✅ Cleaned dataset saved as cleaned_gaming_sales.xlsx

# %%
import os
file_path = os.path.abspath("cleaned_gaming_sales.xlsx")
print("📂 Excel file location:", file_path)
# Out:
# 📂 Excel file location: C:\Users\hp\Desktop\cleaned_gaming_sales.xlsx
